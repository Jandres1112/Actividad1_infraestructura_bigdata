# %%
# !pip install requests pandas openpyxl
# Out:
# Requirement already satisfied: requests in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: pandas in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: openpyxl in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from requests) (2026.2.25)
# Requirement already satisfied: numpy>=1.26.0 in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy scikit-learn
# Out:
# Requirement already satisfied: numpy in /opt/hostedtoolcache/Python/3.12.13/x64/lib/python3.12/site-packages (2.4.3)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/8.9 MB ? eta -:--:--
#    ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/8.9 MB 14.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 24.1 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/35.2 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 20.2/35.2 MB 100.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 110.3 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [scipy]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [joblib]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [joblib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0

# %% [markdown]
# Lectura de los Datos con pandas:
# Se hace un primer analisis y se convierte a excel

# %%
import pandas as pd

# Assuming the CSV file is located at '/content/Centros_Digitales_Rurales_20260322.csv'
# If the file name or path is different, please update it accordingly.
df_datos = pd.read_excel("Centros_Digitales_Rurales_20260322.xlsx")


# Display the first 5 rows of the DataFrame
display(df_datos.head())
# Out:
#   FECHA_CORTE DEPARTAMENTO      MUNICIPIO PRIORIZACION   ZONA  \
# 0  2023-10-31   LA GUAJIRA       RIOHACHA    NO APLICA  RURAL
# 1  2023-10-31      CAQUETA  LA MONTAÃ‘ITA    NO APLICA  RURAL
# 2  2023-10-31   LA GUAJIRA         MAICAO    NO APLICA  RURAL
# 3  2023-10-31     GUAVIARE        CALAMAR    NO APLICA  RURAL
# 4  2023-10-31        CESAR       BECERRIL    PDET BASE  RURAL
#
#   DIFICULTADACCESO NOMBRE_CENTRO_POBLADO        TIPO_SITIO TIPO_CONECTIVIDAD  \
# 0             BAJO         ARROYO ARENAS  SEDES EDUCATIVAS        EN DISEÃ‘O
# 1  SIN INFORMACION                BERLIN  SEDES EDUCATIVAS        EN DISEÃ‘O
# 2  SIN INFORMACION       B. TORRES MAJAY  SEDES EDUCATIVAS        EN DISEÃ‘O
# 3  SIN INFORMACION               CALAMAR  SEDES EDUCATIVAS        EN DISEÃ‘O
# 4             BAJO   CGTO ESTADOS UNIDOS  SEDES EDUCATIVAS        EN DISEÃ‘O
#
#            NOMBRE_INSTITUCION_EDUCATIVA  ...    ESTADOS     TIPO_ENERGIA  \
# 0              CENTRO ETNOEDUCATIVO # 5  ...  OPERACION  EN VERIFICACION
# 1                   I.E.R SIMON BOLIVAR  ...  OPERACION  EN VERIFICACION
# 2  INSTITUCION EDUCATIVA INDIGENA NO. 2  ...  OPERACION  EN VERIFICACION
# 3               C.E. INDIGENA EL ITILLA  ...  OPERACION  EN VERIFICACION
# 4  CENTRO EDUCATIVO INDIGENA SAN GENARO  ...  OPERACION  EN VERIFICACION
#
#   DETALLE_SITIO USUARIOS_ACTIVOS_MES  VELOCIDAD_CONEXION_SUBIDA  \
# 0            IE                    0                       3,75
# 1            IE                    0                       3,00
# 2            IE                    0                       3,75
# 3            IE                    0                       3,00
# 4            IE                    0                       3,00
#
#   VELOCIDAD_CONEXION_BAJADA TRAFICO_MENSUAL_SUBIDA  TRAFICO_MENSUAL_BAJADA  \
# 0                     15,00                      0                       0
# 1                     12,00                      0                       0
# 2                     15,00                      0                       0
# 3                     12,00                      0                       0
# 4                     12,00                      0                       0
#
#    INVERSION  META
# 0  142684114   NaN
# 1  142684114   NaN
# 2  142684114   NaN
# 3  142684114   NaN
# 4  142684114   NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Esploración de datos

# %%
#cantidad de registros duplicados

duplicados_multi = df_datos[df_datos.duplicated(subset=['FECHA_CORTE', 'DEPARTAMENTO', 'MUNICIPIO', 'PRIORIZACION', 'ZONA',
       'DIFICULTADACCESO', 'NOMBRE_CENTRO_POBLADO', 'TIPO_SITIO',
       'TIPO_CONECTIVIDAD', 'NOMBRE_INSTITUCION_EDUCATIVA',
       'NOMBRE_SEDE_EDUCATIVA', 'ESTADOS', 'TIPO_ENERGIA', 'DETALLE_SITIO',
       'USUARIOS_ACTIVOS_MES', 'VELOCIDAD_CONEXION_SUBIDA',
       'VELOCIDAD_CONEXION_BAJADA', 'TRAFICO_MENSUAL_SUBIDA',
       'TRAFICO_MENSUAL_BAJADA', 'INVERSION', 'META'])]
print(duplicados_multi)
# Out:
# Empty DataFrame
# Columns: [FECHA_CORTE, DEPARTAMENTO, MUNICIPIO, PRIORIZACION, ZONA, DIFICULTADACCESO, NOMBRE_CENTRO_POBLADO, TIPO_SITIO, TIPO_CONECTIVIDAD, NOMBRE_INSTITUCION_EDUCATIVA, NOMBRE_SEDE_EDUCATIVA, ESTADOS, TIPO_ENERGIA, DETALLE_SITIO, USUARIOS_ACTIVOS_MES, VELOCIDAD_CONEXION_SUBIDA, VELOCIDAD_CONEXION_BAJADA, TRAFICO_MENSUAL_SUBIDA, TRAFICO_MENSUAL_BAJADA, INVERSION, META]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Conteo de nulos por columna
print("el total de datos nulos por columna es:", df_datos.isnull().sum())
#Dimenciones del df
print("Dimensiones del DataFrame filas x columnas:", df_datos.shape)
# Out:
# el total de datos nulos por columna es: FECHA_CORTE                         0
# DEPARTAMENTO                        0
# MUNICIPIO                           0
# PRIORIZACION                        0
# ZONA                                0
# DIFICULTADACCESO                    0
# NOMBRE_CENTRO_POBLADO               0
# TIPO_SITIO                          0
# TIPO_CONECTIVIDAD                   0
# NOMBRE_INSTITUCION_EDUCATIVA      144
# NOMBRE_SEDE_EDUCATIVA               0
# ESTADOS                             0
# TIPO_ENERGIA                       10
# DETALLE_SITIO                       0
# USUARIOS_ACTIVOS_MES                0
# VELOCIDAD_CONEXION_SUBIDA           0
# VELOCIDAD_CONEXION_BAJADA           0
# TRAFICO_MENSUAL_SUBIDA              0
# TRAFICO_MENSUAL_BAJADA              0
# INVERSION                           0
# META                            14057
# dtype: int64
# Dimensiones del DataFrame filas x columnas: (14057, 21)

# %%
#total de datos nulos en el dataframe
total_nulos = df_datos.isnull().sum().sum()
print("Total de valores nulos en el DataFrame:", total_nulos)
# Out:
# Total de valores nulos en el DataFrame: 14211

# %%
# 3. Mostrar filas con al menos un valor nulo
print("filas con al menos un dato nulo:", df_datos[df_datos.isnull().any(axis=1)])
# Out:
# filas con al menos un dato nulo:       FECHA_CORTE DEPARTAMENTO      MUNICIPIO PRIORIZACION   ZONA  \
# 0      2023-10-31   LA GUAJIRA       RIOHACHA    NO APLICA  RURAL
# 1      2023-10-31      CAQUETA  LA MONTAÃ‘ITA    NO APLICA  RURAL
# 2      2023-10-31   LA GUAJIRA         MAICAO    NO APLICA  RURAL
# 3      2023-10-31     GUAVIARE        CALAMAR    NO APLICA  RURAL
# 4      2023-10-31        CESAR       BECERRIL    PDET BASE  RURAL
# ...           ...          ...            ...          ...    ...
# 14052  2023-10-31        SUCRE        PALMITO    NO APLICA  RURAL
# 14053  2023-10-31         META   VISTAHERMOSA    NO APLICA  RURAL
# 14054  2023-10-31      CORDOBA       CANALETE    NO APLICA  RURAL
# 14055  2023-10-31    RISARALDA    PUEBLO RICO    NO APLICA  RURAL
# 14056  2023-10-31    ANTIOQUIA       CISNEROS    NO APLICA  RURAL
#
#       DIFICULTADACCESO NOMBRE_CENTRO_POBLADO        TIPO_SITIO  \
# 0                 BAJO         ARROYO ARENAS  SEDES EDUCATIVAS
# 1      SIN INFORMACION                BERLIN  SEDES EDUCATIVAS
# 2      SIN INFORMACION       B. TORRES MAJAY  SEDES EDUCATIVAS
# 3      SIN INFORMACION               CALAMAR  SEDES EDUCATIVAS
# 4                 BAJO   CGTO ESTADOS UNIDOS  SEDES EDUCATIVAS
# ...                ...                   ...               ...
# 14052  SIN INFORMACION          ALGODONCILLO  SEDES EDUCATIVAS
# 14053  SIN INFORMACION         ALTO DELICIAS  SEDES EDUCATIVAS
# 14054  SIN INFORMACION          BUENOS AIRES  SEDES EDUCATIVAS
# 14055            MEDIO              BACHICHI  SEDES EDUCATIVAS
# 14056  SIN INFORMACION       VDA. EL CADILLO  SEDES EDUCATIVAS
#
#       TIPO_CONECTIVIDAD                    NOMBRE_INSTITUCION_EDUCATIVA  ...  \
# 0            EN DISEÃ‘O                        CENTRO ETNOEDUCATIVO # 5  ...
# 1            EN DISEÃ‘O                             I.E.R SIMON BOLIVAR  ...
# 2            EN DISEÃ‘O            INSTITUCION EDUCATIVA INDIGENA NO. 2  ...
# 3            EN DISEÃ‘O                         C.E. INDIGENA EL ITILLA  ...
# 4            EN DISEÃ‘O            CENTRO EDUCATIVO INDIGENA SAN GENARO  ...
# ...                 ...                                             ...  ...
# 14052      RADIO ENLACE  C.E. INDIGENA EL MINUTO DE DIOS SEDE PRINCIPAL  ...
# 14053         SATELITAL    CENTRO EDUCATIVO PUERTO LUCAS MARGEN DERECHA  ...
# 14054        EN DISEÃ‘O                  INSTITUCION EDUCATIVA EL LIMON  ...
# 14055   SIN INFORMACION                                        CE CIATO  ...
# 14056        EN DISEÃ‘O                                  I. E. CISNEROS  ...
#
#          ESTADOS        TIPO_ENERGIA DETALLE_SITIO USUARIOS_ACTIVOS_MES  \
# 0      OPERACION     EN VERIFICACION            IE                    0
# 1      OPERACION     EN VERIFICACION            IE                    0
# 2      OPERACION     EN VERIFICACION            IE                    0
# 3      OPERACION     EN VERIFICACION            IE                    0
# 4      OPERACION     EN VERIFICACION            IE                    0
# ...          ...                 ...           ...                  ...
# 14052  OPERACION  RED INTERCONECTADA            IE                  295
# 14053  OPERACION  RED INTERCONECTADA            IE                   54
# 14054  OPERACION     EN VERIFICACION            IE                    0
# 14055  OPERACION  RED INTERCONECTADA            IE                   63
# 14056  OPERACION     EN VERIFICACION            IE                    0
#
#        VELOCIDAD_CONEXION_SUBIDA VELOCIDAD_CONEXION_BAJADA  \
# 0                           3,75                     15,00
# 1                           3,00                     12,00
# 2                           3,75                     15,00
# 3                           3,00                     12,00
# 4                           3,00                     12,00
# ...                          ...                       ...
# 14052                       3,75                     15,00
# 14053                       3,00                     12,00
# 14054                       4,50                     18,00
# 14055                       3,00                     12,00
# 14056                       3,00                     12,00
#
#       TRAFICO_MENSUAL_SUBIDA  TRAFICO_MENSUAL_BAJADA  INVERSION  META
# 0                          0                       0  142684114   NaN
# 1                          0                       0  142684114   NaN
# 2                          0                       0  142684114   NaN
# 3                          0                       0  142684114   NaN
# 4                          0                       0  142684114   NaN
# ...                      ...                     ...        ...   ...
# 14052                      0                     172  142684114   NaN
# 14053                    169                       0  142684114   NaN
# 14054                      0                       0  142684114   NaN
# 14055                      0                       1  162779223   NaN
# 14056                      0                       0  142684114   NaN
#
# [14057 rows x 21 columns]

# %%
df_limpio = df_datos.copy()
df_limpio['NOMBRE_INSTITUCION_EDUCATIVA'] = df_limpio['NOMBRE_INSTITUCION_EDUCATIVA'].fillna("Desconocido")
df_limpio['TIPO_ENERGIA'] = df_limpio['TIPO_ENERGIA'].fillna("Desconocido")

# %%
#Validacion Datos nulos

# 1. Ver si existen nulos en todo el DataFrame
print("Valores nulos en el dataframe:", df_limpio.isnull().any().any())
# 2. Contar nulos por columna
print("cantidad de valores nulos en el dataframe:", df_limpio.isnull().sum())
#copiar el archivo
df_limpio.to_excel("df_limpio.xlsx", index=False)
# Out:
# Valores nulos en el dataframe: True
# cantidad de valores nulos en el dataframe: FECHA_CORTE                         0
# DEPARTAMENTO                        0
# MUNICIPIO                           0
# PRIORIZACION                        0
# ZONA                                0
# DIFICULTADACCESO                    0
# NOMBRE_CENTRO_POBLADO               0
# TIPO_SITIO                          0
# TIPO_CONECTIVIDAD                   0
# NOMBRE_INSTITUCION_EDUCATIVA        0
# NOMBRE_SEDE_EDUCATIVA               0
# ESTADOS                             0
# TIPO_ENERGIA                        0
# DETALLE_SITIO                       0
# USUARIOS_ACTIVOS_MES                0
# VELOCIDAD_CONEXION_SUBIDA           0
# VELOCIDAD_CONEXION_BAJADA           0
# TRAFICO_MENSUAL_SUBIDA              0
# TRAFICO_MENSUAL_BAJADA              0
# INVERSION                           0
# META                            14057
# dtype: int64

# %%
#Validacion tipo de dato
print("las columnas del dataframe limpio:", df_limpio.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14057 entries, 0 to 14056
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   FECHA_CORTE                   14057 non-null  datetime64[us]
#  1   DEPARTAMENTO                  14057 non-null  str
#  2   MUNICIPIO                     14057 non-null  str
#  3   PRIORIZACION                  14057 non-null  str
#  4   ZONA                          14057 non-null  str
#  5   DIFICULTADACCESO              14057 non-null  str
#  6   NOMBRE_CENTRO_POBLADO         14057 non-null  str
#  7   TIPO_SITIO                    14057 non-null  str
#  8   TIPO_CONECTIVIDAD             14057 non-null  str
#  9   NOMBRE_INSTITUCION_EDUCATIVA  14057 non-null  str
#  10  NOMBRE_SEDE_EDUCATIVA         14057 non-null  str
#  11  ESTADOS                       14057 non-null  str
#  12  TIPO_ENERGIA                  14057 non-null  str
#  13  DETALLE_SITIO                 14057 non-null  str
#  14  USUARIOS_ACTIVOS_MES          14057 non-null  int64
#  15  VELOCIDAD_CONEXION_SUBIDA     14057 non-null  str
#  16  VELOCIDAD_CONEXION_BAJADA     14057 non-null  str
#  17  TRAFICO_MENSUAL_SUBIDA        14057 non-null  int64
#  18  TRAFICO_MENSUAL_BAJADA        14057 non-null  int64
#  19  INVERSION                     14057 non-null  int64
#  20  META                          0 non-null      float64
# dtypes: datetime64[us](1), float64(1), int64(4), str(15)
# memory usage: 2.3 MB
# las columnas del dataframe limpio: None

# %%
import pandas as pd
#Generar archivo auditoria
log = []

#----Cantidad datos antes de limpieza----
registros_iniciales = len(df_datos)
log.append(f"Registros iniciales: {registros_iniciales}")

#----Cantidad de datos duplicados----
log.append(f"cantidad de registros duplicados: {duplicados_multi}")

#----cantidad de datos nulos----
log.append(f"Total de valores nulos en el DataFrame: {total_nulos}")


# --- Celda final: generar archivo de auditoría ---
with open("limpio_report.txt", "w", encoding="utf-8") as f:
    f.write("=== Informe de Limpieza de Datos ===\n\n")
    for linea in log:
        f.write(linea + "\n")
