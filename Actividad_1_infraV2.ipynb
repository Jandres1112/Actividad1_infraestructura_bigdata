# %%
pip install requests pandas openpyxl
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import sqlite3
import pandas as pd
import openpyxl

#Extracción de datos
API_URL = "https://jsonplaceholder.typicode.com/posts"


def obtener_datos(url):
    response = requests.get(url)
    if response.status_code == 200:
        return  response.json()
    else:
        raise Exception(f"Error al conectar con la API: {response.status_code}")

#guardar en la base

def guardar_en_base(datos):
    conn = sqlite3.connect('datos_extraidos.db')
    cursor = conn.cursor()

    cursor.execute('''
        CREATE TABLE IF NOT EXISTS POST (
            id INTEGER PRIMARY KEY,
            id_usuario INTEGER,
            titulo TEXT,
            comentario TEXT
        )
    ''')

#insertar datos
    for item in datos:
        cursor.execute('''
            INSERT OR REPLACE INTO POST
            (id, id_usuario, titulo, comentario)
            VALUES (?, ?, ?, ?)
        ''', (
            item['id'],
            item['userId'],
            item['title'],
            item['body']

        ))

    conn.commit()
    conn.close()
# 3. GENERAR EVIDENCIAS (Pandas y Auditoría)
def generar_evidencias(datos):
    # --- Archivo Excel/CSV con Pandas ---
    conn = sqlite3.connect('datos_extraidos.db')
    df_base = pd.read_sql_query("SELECT * FROM POST", conn)
    df_base.to_csv('comentarios.csv', index=False)
    conn.close()

    # --- Archivo de Auditoría .txt ---
    registros_en_api = len(datos)
    registros_en_db = len(df_base)

    with open('logs.txt', 'w', encoding='utf-8') as f:
        f.write("RESUMEN DE AUDITORÍA\n")
        f.write("====================\n")
        f.write(f"Registros extraídos de la API: {registros_en_api}\n")
        f.write(f"Registros guardados en la DB: {registros_en_db}\n")

        if registros_en_api == registros_en_db:
            f.write("\nESTADO: Sincronización Exitosa.\n")
        else:
            f.write("\nESTADO: Discrepancia detectada.\n")

# EJECUCIÓN DEL PROCESO
try:
    print("Iniciando proceso...")
    datos = obtener_datos(API_URL)

    print("Guardando en base de datos...")
    guardar_en_base(datos)

    print("Generando evidencias (CSV y Auditoría)...")
    generar_evidencias(datos)

    print("¡Proceso completado con éxito!")
except Exception as e:
    print(f"Ocurrió un error: {e}")
# Out:
# Iniciando proceso...
# Guardando en base de datos...
# Generando evidencias (CSV y Auditoría)...
# ¡Proceso completado con éxito!

# %%
#crear carpeta ssh
# !mkdir -p /root/.ssh

# %%
#GitHub a known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed

# %%
#verificar llave ssh
# !ls /root/.ssh
# Out:
# known_hosts

# %%
#Generar nueva llave
# !ssh-keygen -t ed25519 -C "jorge.gomez1112@gmail.com" -f /root/.ssh/id_ed25519 -N ""
# Out:
# Generating public/private ed25519 key pair.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:RRxqbyQTv3zOsihIn1gYwG2vX2V5lVxP/ueUgeYh1YQ jorge.gomez1112@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# | . .    ..o. o++o|
# |  o o    =. .E=+.|
# |   o .  = +o = .o|
# |    . .. B+.= . +|
# |     +  So=... .+|
# |    + . .. +   o.|
# |   . * o  . o   .|
# |    o =  . o     |
# |       .. .      |
# +----[SHA256]-----+

# %%
#obtener la llave oublica ssh
# !cat /root/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIG402LDRCWut2mjIk236JvyWmrsAW/yOf+uH/vd74hlF jorge.gomez1112@gmail.com

# %%
#probar conexion
# !ssh -T git@github.com
# Out:
# Hi Jandres1112! You've successfully authenticated, but GitHub does not provide shell access.

# %%
#Agragar github como host confiable
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed
# # github.com:22 SSH-2.0-2b2e4ed

# %%
#clonar repo
# !git clone git@github.com:Jandres1112/Actividad1_infraestructura_bigdata.git
# Out:
# Cloning into 'Actividad1_infraestructura_bigdata'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 111 (delta 45), reused 45 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (111/111), 1.43 MiB | 4.56 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
#configurar correo y usuario github
# !git config --global user.name "Jandres1112"
# !git config --global user.email "jorge.gomez1112@gmail.com"

# %%
#ubicar la carpeta
# %cd /content/Actividad1_infraestructura_bigdata
# Out:
# /content/Actividad1_infraestructura_bigdata

# %%
#Listar la carpeta
# !pwd
# !ls -la
# Out:
# /content/Actividad1_infraestructura_bigdata
# total 1596
# drwxr-xr-x 4 root root    4096 Mar 22 23:52  .
# drwxr-xr-x 1 root root    4096 Mar 22 23:52  ..
# -rw-r--r-- 1 root root   37367 Mar 22 23:52 'Act2(1).ipynb'
# -rw-r--r-- 1 root root   16945 Mar 22 23:52  Actividad_1_infraV2.ipynb
# -rw-r--r-- 1 root root 1485628 Mar 22 23:52  Centros_Digitales_Rurales_20260322.xlsx
# -rw-r--r-- 1 root root   20950 Mar 22 23:52  comentarios.csv
# -rw-r--r-- 1 root root   32768 Mar 22 23:52  datos_extraidos.db
# drwxr-xr-x 8 root root    4096 Mar 22 23:52  .git
# drwxr-xr-x 3 root root    4096 Mar 22 23:52  .github
# -rw-r--r-- 1 root root     147 Mar 22 23:52  logs.txt
# -rw-r--r-- 1 root root     856 Mar 22 23:52  README.md
# -rw-r--r-- 1 root root     504 Mar 22 23:52  requirements.txt

# %%
# !git init
# !git add .
# !git commit -m "Act2_infraV3"
# !git branch -M main
#git remote add origin https://github.com/tuusuario/tu-repo.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/Actividad1_infraestructura_bigdata/.git/
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
